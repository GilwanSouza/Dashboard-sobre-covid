# %%
# !pip install -q werkzeug==2.3.6
# !pip install -q dash==2.3.1
# !pip install -q jupyter_dash==0.4.2

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
from numpy import diff
from dash import Dash, html, dcc, Input, Output
from IPython.display import display, HTML
from plotly.subplots import make_subplots
import plotly.graph_objects as go
# Out:
# <ipython-input-2-40b07ceca34a>:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-2-40b07ceca34a>:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
external_stylesheets = ["https://codepen.io/chriddyp/pen/bWLwgP.css",
                        "https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css",
                        "https://cdn.jsdelivr.net/npm/bootstrap-icons@1.10.3/font/bootstrap-icons.css"]

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# %%
df = pd.read_csv("/content/WHO_time_series.csv")

# %%
soma = df.loc[df['Country'] == 'United States of America'].sum()
soma2 = df.loc[df['Country'] == 'Brazil'].sum()
soma3 = df.loc[df['Country'] == 'India'].sum()

# %%
#Criação dos graficos
figure = px.line(df, x=df["Date_reported"], y=df["Cumulative_cases"], color='Country')

month = pd.DatetimeIndex(df['Date_reported']).month

#Definindo opções como paises para um dropdown
opcoes = list(df['Country'].unique())

opcoes.append("Todos os paises")

#Reescrevendo nomes que tomam muito espaço do grafico
df['Country'] = df['Country'].replace('occupied Palestinian territory, including east Jerusalem', 'Palestinian')

df['Country'] = df['Country'].replace('Northern Mariana Islands (Commonwealth of the)', 'Northern Marina Islands')

#Separando continentes
paises_america_sul = df.loc[df["Country"].isin(['Brazil', 'Argentina', 'Bolivia (Plurinational State of)',
                      'Venezuela (Bolivarian Republic of)', 'Chile', 'Colombia',
                      'Ecuador', 'Guyana', 'French Guiana', 'Paraguay',
                      'Peru', 'Suriname', 'Uruguay'])]

paises_america_norte = df.loc[df["Country"].isin(['United States of America', 'Canada', 'Greenland', 'Mexico'])]

paises_america_central = df.loc[df["Country"].isin(['Guatemala', 'Honduras', 'Costa Rica', 'Panama', 'Belize',
                          'El Salvador', 'Nicaragua'])]

paises_asia = df.loc[df["Country"].isin(['China', 'Thailand', 'Japan', 'Republic of Korea', 'Singapore', 'Nepal',
               'Viet Nam', 'Malaysia', 'Cambodia', 'India', 'Philippines',
               'Russian Federation', 'Afghanistan', 'Pakistan', 'Georgia', 'Armenia',
               'Azerbaijan', 'Kazakhstan', 'Jordan', 'Saudi Arabia', 'Indonesia',
               'Turkey', 'Bangladesh', 'Brunei Darussalam', 'Mongolia', 'Maldives',
               'Myanmar', 'Kyrgyzstan', 'Timor-Leste', 'Syrian Arab Republic', 'Yemen',
               'Tajikistan'])]

paises_europa = df.loc[df["Country"].isin(['France', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
                 'Sweden', 'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Switzerland',
                 'Austria', 'Romania', 'Norway', 'North Macedonia', 'Croatia', 'Denmark',
                 'Estonia', 'Lithuania', 'Netherlands', 'San Marino', 'Monaco', 'Czechia',
                 'Ireland', 'Iceland', 'Luxembourg', 'Portugal', 'Saint Barthélemy',
                 'Gibraltar', 'Poland', 'Slovenia', 'Bosnia and Herzegovina', 'Liechtenstein',
                 'Faroe Islands', 'Holy See', 'Hungary', 'Guernsey', 'Cyprus', 'Jersey',
                 'Montenegro'])]

paises_africa = df.loc[df["Country"].isin(['Egypt', 'Algeria', 'Morocco', 'Senegal', 'Cameroon', 'Nigeria',
                 'South Africa', 'Equatorial Guinea', 'Ethiopia', 'Ghana', 'Gabon',
                 'Guinea', 'Kenya', 'Sudan', 'Namibia', 'Mauritania', 'Congo', 'Suriname',
                 'Rwanda', 'Somalia', 'United Republic of Tanzania', 'Guinea-Bissau',
                 'Liberia', 'Mali', 'Angola', 'Madagascar', 'Mozambique', 'Comoros',
                 'Lesotho'])]

paises_oceania = df.loc[df["Country"].isin(['Australia', 'New Zealand', 'Papua New Guinea'])]

paises_caribe = df.loc[df["Country"].isin(['Cuba', 'Jamaica', 'Bahamas', 'Haiti', 'Puerto Rico', 'Antigua and Barbuda',
                 'Trinidad and Tobago', 'Dominica', 'Barbados', 'Saint Kitts and Nevis',
                 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Cayman Islands',
                 'British Virgin Islands', 'Anguilla', 'Guam', 'Aruba', 'Montserrat',
                 'Bermuda', 'Turks and Caicos Islands', 'Virgin Islands', 'Montserrat'])]

# %%
#Graficos do grafico de pizza para o dropdown
paises_soma = df.loc[df["Country"].isin(['Brazil', 'Argentina', 'Bolivia (Plurinational State of)',
                      'Venezuela (Bolivarian Republic of)', 'Chile', 'Colombia',
                      'Ecuador', 'Guyana', 'French Guiana', 'Paraguay',
                      'Peru', 'Suriname', 'Uruguay'])].groupby('Country')['New_cases'].sum()

paises_soma2 = df.loc[df["Country"].isin(['United States of America', 'Canada', 'Greenland', 'Mexico'])].groupby('Country')['New_cases'].sum()

paises_soma3 = df.loc[df["Country"].isin(['Guatemala', 'Honduras', 'Costa Rica', 'Panama', 'Belize',
                          'El Salvador', 'Nicaragua'])].groupby('Country')['New_cases'].sum()

paises_soma4 = df.loc[df["Country"].isin(['China', 'Thailand', 'Japan', 'Republic of Korea', 'Singapore', 'Nepal',
               'Viet Nam', 'Malaysia', 'Cambodia', 'India', 'Philippines',
               'Russian Federation', 'Afghanistan', 'Pakistan', 'Georgia', 'Armenia',
               'Azerbaijan', 'Kazakhstan', 'Jordan', 'Saudi Arabia', 'Indonesia',
               'Turkey', 'Bangladesh', 'Brunei Darussalam', 'Mongolia', 'Maldives',
               'Myanmar', 'Kyrgyzstan', 'Timor-Leste', 'Syrian Arab Republic', 'Yemen',
               'Tajikistan'])].groupby('Country')['New_cases'].sum()

paises_soma5 = df.loc[df["Country"].isin(['France', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
                 'Sweden', 'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Switzerland',
                 'Austria', 'Romania', 'Norway', 'North Macedonia', 'Croatia', 'Denmark',
                 'Estonia', 'Lithuania', 'Netherlands', 'San Marino', 'Monaco', 'Czechia',
                 'Ireland', 'Iceland', 'Luxembourg', 'Portugal', 'Saint Barthélemy',
                 'Gibraltar', 'Poland', 'Slovenia', 'Bosnia and Herzegovina', 'Liechtenstein',
                 'Faroe Islands', 'Holy See', 'Hungary', 'Guernsey', 'Cyprus', 'Jersey',
                 'Montenegro'])].groupby('Country')['New_cases'].sum()

paises_soma6 = df.loc[df["Country"].isin(['Egypt', 'Algeria', 'Morocco', 'Senegal', 'Cameroon', 'Nigeria',
                 'South Africa', 'Equatorial Guinea', 'Ethiopia', 'Ghana', 'Gabon',
                 'Guinea', 'Kenya', 'Sudan', 'Namibia', 'Mauritania', 'Congo', 'Suriname',
                 'Rwanda', 'Somalia', 'United Republic of Tanzania', 'Guinea-Bissau',
                 'Liberia', 'Mali', 'Angola', 'Madagascar', 'Mozambique', 'Comoros',
                 'Lesotho'])].groupby('Country')['New_cases'].sum()

paises_soma7 = df.loc[df["Country"].isin(['Australia', 'New Zealand', 'Papua New Guinea'])].groupby('Country')['New_cases'].sum()

paises_soma8 = df.loc[df["Country"].isin(['Cuba', 'Jamaica', 'Bahamas', 'Haiti', 'Puerto Rico', 'Antigua and Barbuda',
                 'Trinidad and Tobago', 'Dominica', 'Barbados', 'Saint Kitts and Nevis',
                 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Cayman Islands',
                 'British Virgin Islands', 'Anguilla', 'Guam', 'Aruba', 'Montserrat',
                 'Bermuda', 'Turks and Caicos Islands', 'Virgin Islands', 'Montserrat'])].groupby('Country')['New_cases'].sum()

# %%
#Globo terrestre responsivo

df_planeta = px.data.gapminder().query("year == 2007")
fig_globo_terrestre = px.line_geo(df_planeta, color="continent", projection="orthographic")

# %%
#Grafico de linha
fig = px.line(df, x=df["Date_reported"], y=df["Cumulative_cases"], color="Country", title = "Casos de COVID-19 no mundo em 2020")
fig.update_yaxes(title="Número de casos")
fig.update_xaxes(title="Data")

#Grafico de pizza
figura_pizza = px.pie(paises_soma, values="New_cases", names=paises_soma.index)

app.layout = html.Div(
    lang="pt-br",
    className="ligth",
    children=[
        html.Nav(
            className="navbar fixed-top navbar-dark bg-dark",
            children=[
                html.Div(
                    className="d-flex justify-content-start custom-button-container",
                    children=[
                        html.A("Item 1", className="btn btn-success",style={"margin" : "10px"}),
                        html.A("Item 2", className="btn btn-success",style={"margin" : "10px"}),
                        html.A("Item 3", className="btn btn-success",style={"margin" : "10px"}),
                    ],style={"margin" : "10px"},
                ),
                html.H2(children="Casos de COVID-19 em 2020", className="text-white"),
                html.Form(
                    className="d-flex ml-auto align-items-center",
                    children=[
                        dcc.Input(
                            className="form-control mr-sm-2",
                            type="search",
                            placeholder="Pesquisar",
                            id="search-input",
                            style={"margin" : "5px"}
                        ),
                        html.Button(
                            "Pesquisar",
                            className="btn btn-outline-success my-2 my-sm-0",
                            type="submit",

                        ),
                    ],style={"margin" : "10px"},
                ),
            ],
        ),
        html.Div([
            html.Br()
        ], style={"margin": "50px"}),
        html.H2(
            children="Casos de COVID-19 segundo a OMS", className="text-center mt-2"
        ),
        html.Br(),
        html.Div(className="d-flex justify-content-center", children=[
        html.Div(
            [dcc.Graph(id="globo_terrestre", figure=fig_globo_terrestre, className="p-2")],
            style={"display": "inline-block", "width": "50%", "text-align": "center"},
        ),
            html.Div(
                className="table-responsive mt-4",
                style={"width": "35%", "margin-left": "auto", "margin-right": "auto", "text-align": "center"},
                children=[
                    html.H2(
                        children="Tabela com países mais afetados pelo COVID-19",
                        className="text-center",
                    ),
                    html.Table(
                        className="table table-striped table-bordered table-hover",
                        children=[
                            html.Thead(
                                children=[
                                    html.Tr(
                                        children=[
                                            html.Th(scope="col", children=" "),
                                            html.Th(scope="col", children="País"),
                                            html.Th(scope="col", children="Casos de Covid"),
                                            html.Th(scope="col", children="Nº de mortes"),
                                        ]
                                    )
                                ]
                            ),
                            html.Tbody(
                                children=[
                                    html.Tr(
                                        children=[
                                            html.Td("1"),
                                            html.Td("Estados Unidos da América"),
                                            html.Td(str(soma["New_cases"])),
                                            html.Td(str(soma["New_deaths"])),
                                        ]
                                    ),
                                    html.Tr(
                                        children=[
                                            html.Td("2"),
                                            html.Td("Brasil"),
                                            html.Td(str(soma2["New_cases"])),
                                            html.Td(str(soma2["New_deaths"])),
                                        ]
                                    ),
                                    html.Tr(
                                        children=[
                                            html.Td("3"),
                                            html.Td("India"),
                                            html.Td(str(soma3["New_cases"])),
                                            html.Td(str(soma3["New_deaths"])),
                                        ]
                                    ),
                                ]
                            ),
                        ],
                    ),
                    html.Div(
                        className="dropdown-menu d-inline-block dropdown bg-white border border-gray-300 rounded shadow p-2 center",
                        style={"width": "15%", "margin-right": "45%", "text-align": "center"},
                        children=[
                            dcc.Dropdown(
                                options=[
                                "América do Sul",
                                "América do Norte",
                                "América Central",
                                "Ásia",
                                "Europa",
                                "África",
                                "Caribe",
                                "Oceania",
                                "Todos os continentes",
                                ],
                                value="Todos os continentes",
                                id="lista_continentes",
                            )
                        ],
                    ),
                ],
            ),
        ]),

        html.Div(
            [dcc.Graph(id="grafico_continentes", figure=fig, className="p-2")],
            style={"display": "inline-block", "width": "100%"},
        ),

        html.Div([
            html.H2(children="Gráfico de todos os países", className="text-center mt-2"),
            dcc.Dropdown(
            options=opcoes,
            value="Todos os países",
            id="lista_paises",
            className="dropdown bg-white border border-gray-300 rounded shadow p-2")
        ],style={"width" : "25%", "margin-left": "auto", "margin-right": "auto", "text-align" : "center"}),

        #html.Div([dcc.Graph(id="grafico_paises", figure=fig, className="p-2")],style={"display": "inline-block", "width": "100%"},),

        html.H2(children="Gráficos de todos os países a partir do continente selecionado", className="text-center mt-2"),

        #html.Div([
        #    dcc.Graph(id="subplots_continente", figure=fig_por_continete, className="p-2")],
        #         style={"display": "inline-block", "width": "100%"}),

        html.Div([
            html.Br()
        ], style={"margin": "50px"}
        ),
    ],
)

@app.callback(
    Output("grafico_continentes", "figure"),
    Output("subplots_continente", "figure"),
    Input("lista_continentes", "value"),
    prevent_initial_call=True,
)
def update_output(value):
    fig_grafico_continentes = go.Figure()
    fig_subplots_continente_sul = make_subplots(rows=3, cols=4, start_cell="bottom-left")
    fig_por_continete_norte = make_subplots(rows=3, cols=4, start_cell="bottom-left")
    fig_por_continete_central = make_subplots(rows=2, cols=4, start_cell="bottom-left")
    fig_por_continente_asia = make_subplots(rows=8, cols=4, start_cell="bottom-left")
    fig_por_continente_europa = make_subplots(rows=10, cols=4)
    fig_por_continente_africa = make_subplots(rows=8, cols=4, start_cell="bottom-left")
    fig_por_continente_caribe = make_subplots(rows=8, cols=4, start_cell="bottom-left")

    if value == "América do Sul":
        fig_grafico_continentes = px.line(
            paises_america_sul,
            x="Date_reported",
            y="Cumulative_cases",
            color="Country"
        )

        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Brazil", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Brazil", "Cumulative_cases"]
            ), row=1, col=1)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Argentina", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Argentina", "Cumulative_cases"]
            ), row=1, col=2)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Bolivia (Plurinational State of)", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Bolivia (Plurinational State of)", "Cumulative_cases"]
            ), row=1, col=3)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Venezuela (Bolivarian Republic of)", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Venezuela (Bolivarian Republic of)", "Cumulative_cases"]
            ), row=1, col=4)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Colombia", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Colombia", "Cumulative_cases"]
            ), row=2, col=1)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Ecuador", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Ecuador", "Cumulative_cases"]
            ), row=2, col=2)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Guyana", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Guyana", "Cumulative_cases"]
            ), row=2, col=3)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="French Guiana", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="French Guiana", "Cumulative_cases"]
            ), row=2, col=4)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Paraguay", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Paraguay", "Cumulative_cases"]
            ), row=3, col=1)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Peru", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Peru", "Cumulative_cases"]
            ), row=3, col=2)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Suriname", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Suriname", "Cumulative_cases"]
            ), row=3, col=3)
        fig_por_continente_sul.add_trace(go.Scatter(
            x=paises_america_sul.loc[paises_america_sul["Country"]=="Uruguay", "Date_reported"],
            y=paises_america_sul.loc[paises_america_sul["Country"]=="Uruguay", "Cumulative_cases"]
            ), row=3, col=4)

    elif value == "América do Norte":
        fig_grafico_continentes = px.line(
            paises_america_norte,
            x="Date_reported",
            y="Cumulative_cases",
            color="Country"
        )

        fig_por_continete_norte.add_trace(go.Scatter(
            x=paises_america_norte.loc[paises_america_norte["Country"]=="Brazil", "Date_reported"],
            y=paises_america_norte.loc[paises_america_norte["Country"]=="Brazil", "Cumulative_cases"]
            ), row=1, col=1)
        fig_por_continete_norte.add_trace(go.Scatter(
            x=paises_america_norte.loc[paises_america_norte["Country"]=="Argentina", "Date_reported"],
            y=paises_america_norte.loc[paises_america_norte["Country"]=="Argentina", "Cumulative_cases"]
            ), row=1, col=2)
        fig_por_continete_norte.add_trace(go.Scatter(
            x=paises_america_norte.loc[paises_america_norte["Country"]=="Bolivia (Plurinational State of)", "Date_reported"],
            y=paises_america_norte.loc[paises_america_norte["Country"]=="Bolivia (Plurinational State of)", "Cumulative_cases"]
            ), row=1, col=3)
        fig_por_continete_norte.add_trace(go.Scatter(
            x=paises_america_norte.loc[paises_america_norte["Country"]=="Venezuela (Bolivarian Republic of)", "Date_reported"],
            y=paises_america_norte.loc[paises_america_norte["Country"]=="Venezuela (Bolivarian Republic of)", "Cumulative_cases"]
            ), row=1, col=4)

    elif value == "América Central":
        fig = px.line(
            paises_america_central,
            x=paises_america_central["Date_reported"],
            y=paises_america_central["Cumulative_cases"],
            color="Country",
        )

        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Guatemala", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Guatemala", "Cumulative_cases"]
        ), row=1, col=1)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Honduras", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Honduras", "Cumulative_cases"]
        ), row=1, col=2)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Costa Rica", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Costa Rica", "Cumulative_cases"]
        ), row=1, col=3)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Panama", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Panama", "Cumulative_cases"]
        ), row=1, col=4)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Belize", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Belize", "Cumulative_cases"]
        ), row=2, col=1)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "El Salvador", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "El Salvador", "Cumulative_cases"]
        ), row=2, col=2)
        fig_por_continete_central.add_trace(go.Scatter(
            x=paises_america_central.loc[paises_america_central["Country"] == "Nicaragua", "Date_reported"],
            y=paises_america_central.loc[paises_america_central["Country"] == "Nicaragua", "Cumulative_cases"]
        ), row=2, col=3)

    elif value == "Ásia":
        fig = px.line(
            paises_asia,
            x=paises_asia["Date_reported"],
            y=paises_asia["Cumulative_cases"],
            color="Country",
        )

        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "China", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "China", "Cumulative_cases"]
        ), row=1, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Thailand", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Thailand", "Cumulative_cases"]
        ), row=1, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Japan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Japan", "Cumulative_cases"]
        ), row=1, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Republic of Korea", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Republic of Korea", "Cumulative_cases"]
        ), row=1, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Singapore", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Singapore", "Cumulative_cases"]
        ), row=2, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Nepal", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Nepal", "Cumulative_cases"]
        ), row=2, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Viet Nam", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Viet Nam", "Cumulative_cases"]
        ), row=2, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Malaysia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Malaysia", "Cumulative_cases"]
        ), row=2, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Cambodia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Cambodia", "Cumulative_cases"]
        ), row=3, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "India", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "India", "Cumulative_cases"]
        ), row=3, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Philippines", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Philippines", "Cumulative_cases"]
        ), row=3, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Russian Federation", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Russian Federation", "Cumulative_cases"]
        ), row=3, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Afghanistan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Afghanistan", "Cumulative_cases"]
        ), row=4, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Pakistan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Pakistan", "Cumulative_cases"]
        ), row=4, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Georgia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Georgia", "Cumulative_cases"]
        ), row=4, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Armenia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Armenia", "Cumulative_cases"]
        ), row=4, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Azerbaijan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Azerbaijan", "Cumulative_cases"]
        ), row=5, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Kazakhstan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Kazakhstan", "Cumulative_cases"]
        ), row=5, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Jordan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Jordan", "Cumulative_cases"]
        ), row=5, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Saudi Arabia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Saudi Arabia", "Cumulative_cases"]
        ), row=5, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Indonesia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Indonesia", "Cumulative_cases"]
        ), row=6, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Turkey", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Turkey", "Cumulative_cases"]
        ), row=6, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Bangladesh", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Bangladesh", "Cumulative_cases"]
        ), row=6, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Brunei Darussalam", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Brunei Darussalam", "Cumulative_cases"]
        ), row=6, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Mongolia", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Mongolia", "Cumulative_cases"]
        ), row=7, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Maldives", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Maldives", "Cumulative_cases"]
        ), row=7, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Myanmar", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Myanmar", "Cumulative_cases"]
        ), row=7, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Kyrgyzstan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Kyrgyzstan", "Cumulative_cases"]
        ), row=7, col=4)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Timor-Leste", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Timor-Leste", "Cumulative_cases"]
        ), row=8, col=1)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Syrian Arab Republic", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Syrian Arab Republic", "Cumulative_cases"]
        ), row=8, col=2)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Yemen", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Yemen", "Cumulative_cases"]
        ), row=8, col=3)
        fig_por_continente_asia.add_trace(go.Scatter(
            x=paises_asia.loc[paises_asia["Country"] == "Tajikistan", "Date_reported"],
            y=paises_asia.loc[paises_asia["Country"] == "Tajikistan", "Cumulative_cases"]
        ), row=8, col=4)

    elif value == "Europa":
        fig = px.line(
            paises_europa,
            x=paises_europa["Date_reported"],
            y=paises_europa["Cumulative_cases"],
            color="Country",
        )

        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "France", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "France", "Cumulative_cases"]
        ), row=1, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Germany", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Germany", "Cumulative_cases"]
        ), row=1, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Italy", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Italy", "Cumulative_cases"]
        ), row=1, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Finland", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Finland", "Cumulative_cases"]
        ), row=1, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "United Arab Emirates", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "United Arab Emirates", "Cumulative_cases"]
        ), row=2, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Sweden", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Sweden", "Cumulative_cases"]
        ), row=2, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "The United Kingdom", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "The United Kingdom", "Cumulative_cases"]
        ), row=2, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Spain", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Spain", "Cumulative_cases"]
        ), row=2, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Belgium", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Belgium", "Cumulative_cases"]
        ), row=3, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Other", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Other", "Cumulative_cases"]
        ), row=3, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Switzerland", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Switzerland", "Cumulative_cases"]
        ), row=3, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Austria", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Austria", "Cumulative_cases"]
        ), row=3, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Romania", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Romania", "Cumulative_cases"]
        ), row=4, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Norway", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Norway", "Cumulative_cases"]
        ), row=4, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "North Macedonia", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "North Macedonia", "Cumulative_cases"]
        ), row=4, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Croatia", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Croatia", "Cumulative_cases"]
        ), row=4, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Denmark", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Denmark", "Cumulative_cases"]
        ), row=5, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Estonia", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Estonia", "Cumulative_cases"]
        ), row=5, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Lithuania", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Lithuania", "Cumulative_cases"]
        ), row=5, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Netherlands", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Netherlands", "Cumulative_cases"]
        ), row=5, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "San Marino", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "San Marino", "Cumulative_cases"]
        ), row=6, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Monaco", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Monaco", "Cumulative_cases"]
        ), row=6, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Czechia", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Czechia", "Cumulative_cases"]
        ), row=6, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Ireland", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Ireland", "Cumulative_cases"]
        ), row=6, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Iceland", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Iceland", "Cumulative_cases"]
        ), row=7, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Luxembourg", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Luxembourg", "Cumulative_cases"]
        ), row=7, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Portugal", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Portugal", "Cumulative_cases"]
        ), row=7, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Saint Barthélemy", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Saint Barthélemy", "Cumulative_cases"]
        ), row=7, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Gibraltar", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Gibraltar", "Cumulative_cases"]
        ), row=8, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Poland", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Poland", "Cumulative_cases"]
        ), row=8, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Slovenia", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Slovenia", "Cumulative_cases"]
        ), row=8, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Bosnia and Herzegovina", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Bosnia and Herzegovina", "Cumulative_cases"]
        ), row=8, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Liechtenstein", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Liechtenstein", "Cumulative_cases"]
        ), row=9, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Faroe Islands", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Faroe Islands", "Cumulative_cases"]
        ), row=9, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Holy See", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Holy See", "Cumulative_cases"]
        ), row=9, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Hungary", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Hungary", "Cumulative_cases"]
        ), row=9, col=4)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Guernsey", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Guernsey", "Cumulative_cases"]
        ), row=10, col=1)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Cyprus", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Cyprus", "Cumulative_cases"]
        ), row=10, col=2)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Jersey", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Jersey", "Cumulative_cases"]
        ), row=10, col=3)
        fig_por_continente_europa.add_trace(go.Scatter(
            x=paises_europa.loc[paises_europa["Country"] == "Montenegro", "Date_reported"],
            y=paises_europa.loc[paises_europa["Country"] == "Montenegro", "Cumulative_cases"]
        ), row=10, col=4)

    elif value == "África":
        fig = px.line(
            paises_africa,
            x=paises_africa["Date_reported"],
            y=paises_africa["Cumulative_cases"],
            color="Country",
        )

        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Egypt", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Egypt", "Cumulative_cases"]
        ), row=1, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Algeria", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Algeria", "Cumulative_cases"]
        ), row=1, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Morocco", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Morocco", "Cumulative_cases"]
        ), row=1, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Senegal", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Senegal", "Cumulative_cases"]
        ), row=1, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Cameroon", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Cameroon", "Cumulative_cases"]
        ), row=2, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Nigeria", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Nigeria", "Cumulative_cases"]
        ), row=2, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "South Africa", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "South Africa", "Cumulative_cases"]
        ), row=2, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Equatorial Guinea", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Equatorial Guinea", "Cumulative_cases"]
        ), row=2, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Ethiopia", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Ethiopia", "Cumulative_cases"]
        ), row=3, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Ghana", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Ghana", "Cumulative_cases"]
        ), row=3, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Gabon", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Gabon", "Cumulative_cases"]
        ), row=3, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Guinea", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Guinea", "Cumulative_cases"]
        ), row=3, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Kenya", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Kenya", "Cumulative_cases"]
        ), row=4, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Sudan", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Sudan", "Cumulative_cases"]
        ), row=4, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Namibia", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Namibia", "Cumulative_cases"]
        ), row=4, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Mauritania", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Mauritania", "Cumulative_cases"]
        ), row=4, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Congo", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Congo", "Cumulative_cases"]
        ), row=5, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Suriname", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Suriname", "Cumulative_cases"]
        ), row=5, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Rwanda", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Rwanda", "Cumulative_cases"]
        ), row=5, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Somalia", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Somalia", "Cumulative_cases"]
        ), row=5, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "United Republic of Tanzania", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "United Republic of Tanzania", "Cumulative_cases"]
        ), row=6, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Guinea-Bissau", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Guinea-Bissau", "Cumulative_cases"]
        ), row=6, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Liberia", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Liberia", "Cumulative_cases"]
        ), row=6, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Mali", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Mali", "Cumulative_cases"]
        ), row=6, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Angola", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Angola", "Cumulative_cases"]
        ), row=7, col=1)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Madagascar", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Madagascar", "Cumulative_cases"]
        ), row=7, col=2)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Mozambique", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Mozambique", "Cumulative_cases"]
        ), row=7, col=3)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Comoros", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Comoros", "Cumulative_cases"]
        ), row=7, col=4)
        fig_por_continente_africa.add_trace(go.Scatter(
            x=paises_africa.loc[paises_africa["Country"] == "Lesotho", "Date_reported"],
            y=paises_africa.loc[paises_africa["Country"] == "Lesotho", "Cumulative_cases"]
        ), row=8, col=1)

    elif value == "Caribe":
        fig = px.line(
            paises_caribe,
            x=paises_caribe["Date_reported"],
            y=paises_caribe["Cumulative_cases"],
            color="Country",
        )

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Cuba", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Cuba", "Cumulative_cases"]
        ), row=1, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Jamaica", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Jamaica", "Cumulative_cases"]
        ), row=1, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Bahamas", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Bahamas", "Cumulative_cases"]
        ), row=1, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Haiti", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Haiti", "Cumulative_cases"]
        ), row=2, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Puerto Rico", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Puerto Rico", "Cumulative_cases"]
        ), row=2, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Antigua and Barbuda", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Antigua and Barbuda", "Cumulative_cases"]
        ), row=2, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Trinidad and Tobago", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Trinidad and Tobago", "Cumulative_cases"]
        ), row=3, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Dominica", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Dominica", "Cumulative_cases"]
        ), row=3, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Barbados", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Barbados", "Cumulative_cases"]
        ), row=3, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Saint Kitts and Nevis", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Saint Kitts and Nevis", "Cumulative_cases"]
        ), row=4, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Saint Lucia", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Saint Lucia", "Cumulative_cases"]
        ), row=4, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Saint Vincent and the Grenadines", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Saint Vincent and the Grenadines", "Cumulative_cases"]
        ), row=4, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Cayman Islands", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Cayman Islands", "Cumulative_cases"]
        ), row=5, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "British Virgin Islands", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "British Virgin Islands", "Cumulative_cases"]
        ), row=5, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Anguilla", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Anguilla", "Cumulative_cases"]
        ), row=5, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Guam", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Guam", "Cumulative_cases"]
        ), row=6, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Aruba", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Aruba", "Cumulative_cases"]
        ), row=6, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Montserrat", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Montserrat", "Cumulative_cases"]
        ), row=6, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Bermuda", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Bermuda", "Cumulative_cases"]
        ), row=7, col=1)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Turks and Caicos Islands", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Turks and Caicos Islands", "Cumulative_cases"]
        ), row=7, col=2)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Virgin Islands", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Virgin Islands", "Cumulative_cases"]
        ), row=7, col=3)

        fig_por_continente_caribe.add_trace(go.Scatter(
            x=paises_caribe.loc[paises_caribe["Country"] == "Montserrat", "Date_reported"],
            y=paises_caribe.loc[paises_caribe["Country"] == "Montserrat", "Cumulative_cases"]
        ), row=8, col=1)

        fig_por_continente_oceania = make_subplots(rows=1, cols=3, start_cell="bottom-left")

        fig_por_continente_oceania.add_trace(go.Scatter(
            x=paises_oceania.loc[paises_oceania["Country"] == "Australia", "Date_reported"],
            y=paises_oceania.loc[paises_oceania["Country"] == "Australia", "Cumulative_cases"]
        ), row=1, col=1)

        fig_por_continente_oceania.add_trace(go.Scatter(
            x=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Date_reported"],
            y=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Cumulative_cases"]
        ), row=1, col=2)

        fig_por_continente_oceania.add_trace(go.Scatter(
            x=paises_oceania.loc[paises_oceania["Country"] == "Papua New Guinea", "Date_reported"],
            y=paises_oceania.loc[paises_oceania["Country"] == "Papua New Guinea", "Cumulative_cases"]
        ), row=1, col=3)

    elif value == "Oceania":
        fig = px.line(
            paises_oceania,
            x=paises_oceania["Date_reported"],
            y=paises_oceania["Cumulative_cases"],
            color="Country",
        )



    else:
        fig = px.line(
            df, x=df["Date_reported"], y=df["Cumulative_cases"], color="Country"
        )

    return fig, fig_por_continente

@app.callback(
    Output("grafico_pizza_continentes", "figure"),
    Input("lista_continentes_pizza", "value")
)
def update_output_pizza(value):
    if value == "América do Sul":
        figura_pizza = px.pie(
            paises_soma,
            values="New_cases",
            names=paises_soma.index
        )

    elif value == "América do Norte":
        figura_pizza = px.pie(
            paises_soma2,
            values="New_cases",
            names=paises_soma2.index
        )

    elif value == "América Central":
        figura_pizza = px.pie(paises_soma3, values="New_cases", names=paises_soma3.index)

    elif value == "Ásia":
        figura_pizza = px.pie(
            paises_soma4,
            values="New_cases",
            names=paises_soma4.index
        )

    elif value == "Europa":
        figura_pizza = px.pie(
            paises_soma5,
            values="New_cases",
            names=paises_soma5.index
        )

    elif value == "África":
        figura_pizza = px.pie(
            paises_soma6,
            values="New_cases",
            names=paises_soma6.index
        )

    elif value == "Caribe":
        figura_pizza = px.pie(
            paises_soma7,
            values="New_cases",
            names=paises_soma7.index
        )

    elif value == "Oceania":
        figura_pizza = px.pie(
            paises_soma8,
            values="New_cases",
            names=paises_soma8.index
        )

    else:
        figura_pizza = px.pie(
            df,
            values="New_cases",
            names=df.index
        )

    return figura_pizza

@app.callback(Output("grafico_paises", "figure"), Input("lista_paises", "value"))
def update_output(value):
    if value == "Todos os paises":
        fig = px.line(
            df, x=df["Date_reported"], y=df["Cumulative_cases"], color="Country"
        )

    else:
        tabela_filtrada = df.loc[df["Country"] == value, :]
        fig = px.line(
            tabela_filtrada,
            x=tabela_filtrada["Date_reported"],
            y=tabela_filtrada["Cumulative_cases"],
            color="Country",
        )

    return fig

if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
# Dash app running on:

# %%
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=("Plot 1", "Plot 2", "Plot 3", "Plot 4"), shared_yaxes=True)

fig.add_trace(
    go.Scatter(x=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Date_reported"],
              y=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Cumulative_cases"]
        ), row=1, col=1)

fig.add_trace(
    go.Scatter(x=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Date_reported"],
              y=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Cumulative_cases"]
        ), row=1, col=2)

fig.add_trace(
    go.Scatter(x=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Date_reported"],
              y=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Cumulative_cases"]
        ), row=2, col=1)

fig.add_trace(
    go.Scatter(x=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Date_reported"],
              y=paises_oceania.loc[paises_oceania["Country"] == "New Zealand", "Cumulative_cases"]
        ), row=2, col=2)

fig.update_layout(height=500, width=700,
                  title_text="Multiple Subplots with Titles")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
paises_casos_acumulados = df_covid.groupby('Country').mean(numeric_only=True)['Cumulative_cases'].sort_values(ascending=False)[0:5]

# %%
df_fig3 = df_covid.query('Country == "Brazil" or Country == "India"  or Country == "USA"')
fig3_covid = px.histogram(df_fig3, x = 'Date_reported', y = 'Cumulative_cases', color = 'Country',
                     title = 'Casos Acumulados de Covid-19 - Brasil, India e USA',
                          barmode="group")
